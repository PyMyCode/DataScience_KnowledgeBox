# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder_unfiltered.csv')
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.shape
# Out:
# (3313, 6)

# %%
df.year.describe()
# Out:
# count    3313.000000
# mean     1980.293088
# std        16.931879
# min      1950.000000
# 25%      1967.000000
# 50%      1982.000000
# 75%      1996.000000
# max      2007.000000
# Name: year, dtype: float64

# %%
lower_limit = 0
lower_limit = lower_limit * 10e6

year = 1950 #between 1950 and 2007
print(lower_limit)
# Out:
# 0.0

# %%
df_subset = df[
    (df["pop"]>lower_limit) & 
    (df["year"]==year)
    ]

# %%
df_subset
# Out:
#               country continent  year   lifeExp        pop     gdpPercap
# 72          Australia   Oceania  1950  69.02000    8267337  10031.121380
# 128           Austria    Europe  1950  64.88000    6935100   5733.098114
# 251           Belgium    Europe  1950  66.35000    8639369   7990.465840
# 308            Belize  Americas  1950  57.67300      65797   1731.132728
# 395          Bulgaria    Europe  1950  61.39000    7250500   2131.563149
# 500            Canada  Americas  1950  68.28000   14011422  10581.265520
# 688        Costa Rica  Americas  1950  55.60000     866982   2439.821535
# 725              Cuba  Americas  1950  55.71400    5784797   5180.436272
# 746    Czech Republic    Europe  1950  64.43000    8925122   6690.749648
# 804           Denmark    Europe  1950  70.33000    4271000   9675.477458
# 986           Finland    Europe  1950  64.24000    4008900   5845.626316
# 1044           France    Europe  1950  66.39000   41828673   6595.926631
# ...
