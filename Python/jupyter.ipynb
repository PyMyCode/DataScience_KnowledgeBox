# %% [markdown]
# ## Example

# %%
a = [1, 2, 3 , 4, 5]
b = [-2, -4, -8, -16, -34]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(a, b)
plt.show()

# %% [markdown]
# ## Kernels
#
# - Computational engine that executes the code in the NB
#
# ## Architecture
#
# ### Execution Process
# Client is the interface (vscode, chrome) -> sends code to Kernel
# Kernel executes the code -> returns to client
#
# ### Convertion Process
# NB file -> preprocessor -> Exporter -> Exported file
